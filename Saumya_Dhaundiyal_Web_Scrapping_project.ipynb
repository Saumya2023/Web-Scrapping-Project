# %% [markdown]
# <a href="https://colab.research.google.com/github/Saumya2023/Web-Scrapping-Project/blob/main/Saumya_Dhaundiyal_Web_Scrapping_project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Import the article from Goof firms, which stated the review of a software development firm "Webfx"
import requests
from bs4 import BeautifulSoup

# Make the HTTP request
url = 'https://www.goodfirms.co/company/webfx/reviews'
response = requests.get(url)
soup = BeautifulSoup(response.text, 'html.parser')

# Find all elements with the class "review-summary"
reviews = soup.find_all(class_='review-summary')

# Take the first 5 reviews
for i, review in enumerate(reviews[:5]):
    print(f"Review {i + 1}:")
    print(review.get_text())
    print("\n")
# Out:
# Review 1:
#
# Review Summary
#
# WebFX is outstanding at what they do and is one of the best SEO and digital marketing companies in the country. I've worked with WebFX for many years and they always bring new ideas to our campaigns which deliver strong results. In addition to strong performance, everyone that I've ever spoken with is extremely friendly and WebFX provides excellent customer service.
#
#
#
#
# Review 2:
#
# Review Summary
#
# The best web designers in the town and they are best in whole town as my website was beautifully designed and it was ranked too in the best websites.
#
#
#
#
# Review 3:
#
# Review Summary
#
# The guys are very professional that deliver best in this industries.
#
#
#
#
# Review 4:
#
# Review Summary
#
# Experience with RankSnack was Great I like there working approach and overall client handling skills, They ranked my website in Google for the selected Keywords.
#
#
#
#
# Review 5:
#
# Review Summary
#
# The team at WebFX makes my life so much easier! Seamless planning of events and support during. The team is very responsive and fun to work with! I can't say enough about them! Wonderful!

# %%
print(review)
# Out:
# <div class="review-summary">
# <h3>Review Summary</h3>
# <div class="summary" itemprop="description">
# The team at WebFX makes my life so much easier! Seamless planning of events and support during. The team is very responsive and fun to work with! I can't say enough about them! Wonderful!
# </div>
# </div>

# %%
import pandas as pd
from urllib.parse import urlparse
import numpy as np
import nltk.data

# %%
def parse_elements(url,element):
    session = HTMLSession()
    r = session.get(url)
    elements = r.html.find(element)
    return elements

# %%
url = 'https://www.goodfirms.co/company/webfx/reviews'

# %%
# Parse the HTML content with Beautiful Soup
soup = BeautifulSoup(response.content, 'html.parser')

# Remove unwanted elements (script, style, comments, etc.)
for element in soup(['script', 'style', 'comment']):
    element.extract()

# Extract the visible text
text = soup.get_text(separator=' ')

# Print the extracted text
print(text)
# Out:
#
#
#
#
#
#
#
#
#
#
#
#  WebFX Reviews & Company Profile | GoodFirms
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  Sign In
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  Find Services
#
#
#
#  Software Development
#
#
#  Custom Software Developers
#  Blockchain Development
#  Java Development
#  PHP Development
#  Python Development
#  React Development
#  AngularJS Development
#  NodeJS Development
#  .Net Development
#  Software Testing
#
#
#
#
#  Web & App Development
#
#
#  Mobile App Development
#  Web Development
#  E-Commerce Development
#  Android App Development
#  iPhone App Development
#  Flutter App Development
#  WordPress Development
#  Magento Development
#  Shopify Development
#  WooCommerce Development
#
#
#
#
#  Design
#
#
#  Web Design
#  Graphic Design
#  UX Design
#  Product Design
#  Logo Design
#  Digital Design
#  Illustrators
#  Packaging Design
#  Print Design
#  Animation & Multimedia
#
#
#
#
#  Marketing & Advertising
#
#
#  Digital Marketing
#  SEO Agencies
#  Advertising
#  Social Media Marketing
#  Content Marketing
#  PPC Agencies
#  Branding
#  Email Marketing
#  Market Research
#  Influencer Marketing
#
#
#
#
#  Latest Tech
#
#
#  Artificial Intelligence
#  AR & VR Development
#  IoT Development
#  Bot Development
#  DevOps
#  Progressive Web App
#  Robotic Process Automation
#  ChatGPT Development
#  Metaverse Development
#
#
#
#
#  Business & IT Services
#
#
#  IT Services
#  Big Data Companies
#  Implementation Services
#  Cloud Computing Services
#  Business Services
#  IT Consulting
#  BPO Services
#  Admin Services
#  Translation Services
#  Supply Chain & Logistics
#
#
#
#
#  Browse all categories
#
#
#
#
#
#  Find Software
#
#
#
#
#
#  Write a Review
#  Insights
#  Blogs
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  WebFX
#  The Digital Marketing Agency That Drives Results
#
#
#
#
#  4.8
#
#
#  24  Reviews
#
#
#  Visit website
#
#
#
#  Write a Review
#
#
#
#
#  Verified Profile
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  Overview
#
#
#  Focus
#
#
#  Portfolio
#
#
#  Reviews
#
#
#  Visit website
#
#
#
#
#
#
#
#
#
#  WebFX is a tech-enabled digital marketing solutions provider, and we create custom strategies for each of our clients based on their needs and goals. Our team is made up of award-winning marketers, designers, and developers, and we know what it takes to get real results online. We also keep the focus on the metrics that mean the most, like leads and revenue generated. We know that hitting these goals is what moves businesses forward, and we believe that our client’s success is the best measure of our own performance.
#
#
#  Read more
#
#
#
#
#
#
#
#
#  $100 - $149/hr
#
#
#
#
#
#
#
#  250 - 999
#
#
#
#
#
#
#
#  1996
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Locations
#
#  Show All
#  Show Less
#
#
#
#
# United States
#
#
#  1705 North Front Street ,
#  Harrisburg ,
#  Pennsylvania
#  17102
#
#  8448562428
#
#
#
# United States
#
#
#  600 Third Avenue, 2nd Floor ,
#  NYC ,
#  New York
#  10016
#
#  8448562428
#
#
#
# United States
#
#
#  1000 Parkwood Circle SE #900 ,
#  Atlanta ,
#  Georgia
#  30339
#
#  8448562428
#
#
#
# United States
#
#
#  325 Chestnut Street Suite 800 ,
#  Philadelphia ,
#  Pennsylvania
#  19106
#
#  8448562428
#
#
#
#
#
#
#
#
#  Focus Areas
#
#  Service Focus
#
#
# 70%
#
#
# 10%
#
#
# 10%
#
#
# 10%
#
#
#
#  Digital Marketing
#  Web Development
#  Web Designing (UI/UX)
#  E-commerce Development
#
#
#
#
#
#
# Digital Marketing
#
#
# 70%
#
#
#
#
# Web Development
#
#
# 10%
#
#
#
#
# Web Designing (UI/UX)
#
#
# 10%
#
#
#
#
# E-commerce Development
#
#
# 10%
#
#
#
#
#
#
#
#
#
#
#  Client Focus
#
#
# 55%
#
#
# 5%
#
#
# 40%
#
#
#
#  Medium Business
#  Large Business
#  Small Business
#
#
#
#
#
#  Medium Business($10M - $1B)
#  55%
#
#
#  Large Business(> $1B)
#  5%
#
#
#  Small Business(< $10M)
#  40%
#
#
#
#
#
#
#
#
#
#
#
#
#  WebFX Clients & Portfolios
#
#
#
#
#
#
#
#
#
#
#
#
#  View Portfolio
#
#
#  Energex
#
#
#
#
#
#
#
#
#
#
#
#  $10001 to $50000
#
#
#
#  12 weeks
#
#
#
#  Consumer Products
#
#
#  Website redesign for a leading manufacturer of premium wood pellets. The site features unique icons and imagery with a responsive design and strong calls to action.
#
#
#  Web App
#
#
#
#
#
#
#
#  View Portfolio
#
#
#  NeoSystems
#
#
#
#
#
#
#
#
#
#
#
#  $10001 to $50000
#
#
#
#  20 weeks
#
#
#
#  Information Technology
#
#
#  Website redesign for a software company. We launched a complete redesign of their website to better showcase the amazing products and software that they offer.
#
#
#  Web App
#
#
#
#
#
#
#
#
#
#  WebFX Reviews
#
#
#
#
#
#  4.8
#  24 Reviews
#
#
#
#  Services:
#
#
#
#
#
#
#
#  All
# Services
#
#  Digital Marketing
#  Web Development
#  Web Designing (UI/UX)
#
#
#
#
#  Sort By:
#
#
#
#
#
#
#
#
# Relevance
#
#
# Most Recent
#
#
# Rating: high to low
#
#
# Rating: low to high
#
#
#
#
#  Write a Review
#
#
#
#
#
#
#
#
#
#  Lakshmi Nedungadi , Business Strategist at Self Employed
#  Posted 11 months ago
#
#
#
#  They helped us increase the organic traffic.
#
#
#
#  Rating Breakdown
#
#
#  Quality
#
#
#
#
#
#  Schedule & Timing
#
#
#
#
#
#  Communication
#
#
#
#
#
#  Overall Rating
#
#
#
#
#
#
#
#  Project Detail
#
#
#
#  $50001 to $200000
#
#
#
#
#
#  Completed
#
#
#
#
#  Share it on
#
#
#
#
#
#
#
#
#
#  Review Summary
#
# WebFX is outstanding at what they do and is one of the best SEO and digital marketing companies in the country. I've worked with WebFX for many years and they always bring new ideas to our campaigns which deliver strong results. In addition to strong performance, everyone that I've ever spoken with is extremely friendly and WebFX provides excellent customer service.
#
#
#
#
#  What was the project name that you have worked with WebFX?
#  Blockchain development and and crypto exchange
#
#
#  Describe your project in brief
#  I am thrilled to share my experience working with Cryptosoftwares. Their high quality service has amazed me to the core. I have worked with them for multiple projects like blockchain development and crypto exchange
#
#
#  What is it about the company that you appreciate the most?
#  The people and the results that WebFX was able to achieve on our digital campaigns.
#
#
#  What was it about the company that you didn't like which they should do better?
#  The people and the results that WebFX was able to achieve on our digital campaigns.
#
#
#  Show full review
#  Hide full review
#
#
#
#
#
#
#
#
#
#   Chester Peters  at WebFX
#  Posted on Jun 20, 2022
#
#
#
#  They've been nothing but helpful, responsive, and considerate of feedback
#
#
#
#  Rating Breakdown
#
#
#  Quality
#
#
#
#
#
#  Schedule & Timing
#
#
#
#
#
#  Communication
#
#
#
#
#
#  Overall Rating
#
#
#
#
#
#
#
#  Project Detail
#
#
#
#  $0 to $10000
#
#
#
#
#  Share it on
#
#
#
#
#
#
#
#
#
#  Review Summary
#
# The best web designers in the town and they are best in whole town as my website was beautifully designed and it was ranked too in the best websites.
#
#
#
#
#  What is it about the company that you appreciate the most?
#  {"1":"Help was quick and helpful throughout the website building process, and the after-sales support was exceptional as well"}
#
#
#  What was it about the company that you didn't like which they should do better?
#  {"1":"Your requests will be met with prompt honesty and straightforwardness. but sometime no time work not provied"}
#
#
#  Show full review
#  Hide full review
#
#
#
#
#
#
#
#
#
#  P S Kumar
#  Posted on Aug 06, 2021
#
#
#
#  Good Services
#
#
#
#  Rating Breakdown
#
#
#  Quality
#
#
#
#
#
#  Schedule & Timing
#
#
#
#
#
#  Communication
#
#
#
#
#
#  Overall Rating
#
#
#
#
#
#
#
#  Share it on
#
#
#
#
#
#
#
#
#
#  Review Summary
#
# The guys are very professional that deliver best in this industries.
#
#
#
#
#  Show full review
#  Hide full review
#
#
#
#
#
#
#
#
#
#  Emma Gomez
#  Posted on Apr 08, 2021
#
#
#
#  Great Exper
#
#
#
#  Rating Breakdown
#
#
#  Quality
#
#
#
#
#
#  Schedule & Timing
#
#
#
#
#
#  Communication
#
#
#
#
#
#  Overall Rating
#
#
#
#
#
#
#
#  Share it on
#
#
#
#
#
#
#
#
#
#  Review Summary
#
# Experience with RankSnack was Great I like there working approach and overall client handling skills, They ranked my website in Google for the selected Keywords.
#
#
#
#
#  Show full review
#  Hide full review
#
#
#
#
#
#
#
#
#
#  Noah John
#  Posted on Dec 25, 2020
#
#
#
#  Wonderful!
#
#
#
#  Rating Breakdown
#
#
#  Quality
#
#
#
#
#
#  Schedule & Timing
#
#
#
#
#
#  Communication
#
#
#
#
#
#  Overall Rating
#
#
#
#
#
#
#
#  Share it on
#
#
#
#
#
#
#
#
#
#  Review Summary
#
# The team at WebFX makes my life so much easier! Seamless planning of events and support during. The team is very responsive and fun to work with! I can't say enough about them! Wonderful!
#
#
#
#
#  Show full review
#  Hide full review
#
#
#
#
#
#
#
#
#
#  Dai Software
#  Posted on Dec 01, 2020
#
#
#
#  multi vendor ecommerce website price
#
#
#
#  Rating Breakdown
#
#
#  Quality
#
#
#
#
#
#  Schedule & Timing
#
#
#
#
#
#  Communication
#
#
#
#
#
#  Overall Rating
#
#
#
#
#
#
#
#  Share it on
#
#
#
#
#
#
#
#
#
#  Review Summary
#
# I completely agree, It is great. And I am always surprised when I read posts about the food. This great content. I have learned something powerful today. multi vendor ecommerce website price
#
#
#
#
#  Show full review
#  Hide full review
#
#
#
#
#
#
#
#
#
#  GVI TECH
#  Posted on Aug 20, 2020
#
#
#
#  Seo service provider
#
#
#
#  Rating Breakdown
#
#
#  Quality
#
#
#
#
#
#  Schedule & Timing
#
#
#
#
#
#  Communication
#
#
#
#
#
#  Overall Rating
#
#
#
#
#
#
#
#  Share it on
#
#
#
#
#
#
#
#
#
#  Review Summary
#
# GVI Technology provides the best SEO service.In SEO service these works include like more brand awareness, more business growth, and more leads, more traffic etc.when you gain more visibility you will find the more no of visitors to your website, that's why the traffic also increases. Lastly, you will find your development in your business.
#
#
#
#
#  Show full review
#  Hide full review
#
#
#
#
#
#
#
#
#
#  Anil Sharma  at Dr. Anil sharma laparoscopy
#  Posted on Jul 10, 2020
#
#
#
#  Digital marketing
#
#
#
#  Rating Breakdown
#
#
#  Quality
#
#
#
#
#
#  Schedule & Timing
#
#
#
#
#
#  Communication
#
#
#
#
#
#  Overall Rating
#
#
#
#
#
#
#
#  Share it on
#
#
#
#
#
#
#
#
#
#  Review Summary
#
# Great relationship building and communication throughout the company. Very impressive work.
# http://www.anilsharmalaparoscopy.com/hernia.php
#
#
#
#
#  Show full review
#  Hide full review
#
#
#
#
#
#
#
#
#
#  Jack Houston
#  Posted on Apr 21, 2020
#
#
#
#  A top tier experience
#
#
#
#  Rating Breakdown
#
#
#  Quality
#
#
#
#
#
#  Schedule & Timing
#
#
#
#
#
#  Communication
#
#
#
#
#
#  Overall Rating
#
#
#
#
#
#
#
#  Project Detail
#
#
#
#  $0 to $10000
#
#
#
#
#  Share it on
#
#
#
#
#
#
#
#
#
#  Review Summary
#
# Great relationship building and communication throughout the company. Very impressive work.
#
#
#
#
#  What is it about the company that you appreciate the most?
#  Great people and quick turnaround
#
#
#  What was it about the company that you didn't like which they should do better?
#  No negatives at all
#
#
#  Show full review
#  Hide full review
#
#
#
#
#
#
#
#
#
#  Raymond McClure
#  Posted on Feb 14, 2020
#
#
#
#  Great experience!
#
#
#
#  Rating Breakdown
#
#
#  Quality
#
#
#
#
#
#  Schedule & Timing
#
#
#
#
#
#  Communication
#
#
#
#
#
#  Overall Rating
#
#
#
#
#
#
#
#  Project Detail
#
#
#
#  $10001 to $50000
#
#
#
#
#  Share it on
#
#
#
#
#
#
#
#
#
#  Review Summary
#
# Overall very happy with WebFX - always there when I need them. Amanda has been a huge help and she's got a great team backing her up day in and day out.
#
#
#
#
#  What is it about the company that you appreciate the most?
#  Always there when I need them for random questions
#
#
#  What was it about the company that you didn't like which they should do better?
#  I don't always understand the acronyms in the digital marketing world.
#
#
#  Show full review
#  Hide full review
#
#
#
#
#
#
#
#
#
#  Vaibhav Kandpal , Digital Strategy Consultant at TIS
#  Posted on May 17, 2019
#
#
#
#  Great Company
#
#
#
#  Rating Breakdown
#
#
#  Quality
#
#
#
#
#
#  Schedule & Timing
#
#
#
#
#
#  Communication
#
#
#
#
#
#  Overall Rating
#
#
#
#
#
#
#
#  Share it on
#
#
#
#
#
#
#
#
#
#  Review Summary
#
# Great compapny to avail services of. Will be returning to them again.
#
#
#
#
#  Show full review
#  Hide full review
#
#
#
#
#
#
#
#
#
#  James Ritchie Espino Ostman , Co Op / Validation Specialist at Barry-Wehmiller Design Group
#  Posted on Mar 13, 2019
#
#
#
#  Highly recommend this company!
#
#
#
#  Rating Breakdown
#
#
#  Quality
#
#
#
#
#
#  Schedule & Timing
#
#
#
#
#
#  Communication
#
#
#
#
#
#  Overall Rating
#
#
#
#
#
#
#
#  Project Detail
#
#
#
#  $10001 to $50000
#
#
#
#
#  Share it on
#
#
#
#
#
#
#
#
#
#  Review Summary
#
# Will and the rest of the WebFX team knows PPC really well. I think they have 6-7 people working on our account at any given time. Strongly suggest!
#
#
#
#
#  What is it about the company that you appreciate the most?
#  Our cost per lead has decreased by 25% over the past 6 months!
#
#
#  What was it about the company that you didn't like which they should do better?
#  Not sure, the setup took a few weeks with all the research and strategy planning, however now our CPL has decreased a lot worth the extra setup time.
#
#
#
#  Show full review
#  Hide full review
#
#
#
#
#
#
#
#
#
#  Jenny Blevins , Business Analyst at Dell
#  Posted on Feb 19, 2019
#
#
#
#  Trustworthy company
#
#
#
#  Rating Breakdown
#
#
#  Quality
#
#
#
#
#
#  Schedule & Timing
#
#
#
#
#
#  Communication
#
#
#
#
#
#  Overall Rating
#
#
#
#
#
#
#
#  Share it on
#
#
#
#
#
#
#
#
#
#  Review Summary
#
# I have worked with them for 2 projects now, including one at my old position. They approach all projects big or small the same way. I reccomended a family friend use them for their landscaping business and they didn't have a huge budget but WebFX was so very helpful to them and helped educate them.
#
#
#
#
#  Show full review
#  Hide full review
#
#
#
#
#
#
#
#
#
#  Robert Lee Barner , Senior Manager Quality Engineering at Amicus Therapeutics
#  Posted on Feb 18, 2019
#
#
#
#  This was the best website/marketing company we have ever worked with!
#
#
#
#  Rating Breakdown
#
#
#  Quality
#
#
#
#
#
#  Schedule & Timing
#
#
#
#
#
#  Communication
#
#
#
#
#
#  Overall Rating
#
#
#
#
#
#
#
#  Project Detail
#
#
#
#  $10001 to $50000
#
#
#
#
#  Share it on
#
#
#
#
#
#
#
#
#
#  Review Summary
#
# The overall experience was great! Our website looks amazing, and we are generating solid leads from our PPC campaign. WebFX is a very professional company, and our project manager (Kristina) was a rock star!
#
#
#
#
#  What is it about the company that you appreciate the most?
#  The website looks amazing!
#
#
#  What was it about the company that you didn't like which they should do better?
#  Not really an improvement but we learned how hard good web design is to do! The website redesign was a ton of work, and took 2 weeks longer then we wanted it to. I didn't realize building a website would be so much work.
#
#
#  Show full review
#  Hide full review
#
#
#
#
#
#
#
#
#
#  Greg Shambaugh , Teacher at West Shore School District
#  Posted on Feb 15, 2019
#
#
#
#  The communication is unparalelled!
#
#
#
#  Rating Breakdown
#
#
#  Quality
#
#
#
#
#
#  Schedule & Timing
#
#
#
#
#
#  Communication
#
#
#
#
#
#  Overall Rating
#
#
#
#
#
#
#
#  Project Detail
#
#
#
#  $50001 to $200000
#
#
#
#
#  Share it on
#
#
#
#
#
#
#
#
#
#  Review Summary
#
# They are a real company! At first we weren't sure about going to a larger agency, so we opted to choose a smaller boutique company. That was a big mistake! Our main poc got married and was out for 3 weeks, well nothing got done for 3 weeks. We never have to worry about this with WebFX. Paul is our main marketer, however there is a small army behind him so we are always taken care of, and their project managment software ensure emails, communication and task are never missed! We love it!
#
#
#
#
#  What is it about the company that you appreciate the most?
#  They are a real company and have driven our company real leads!
#
#
#  What was it about the company that you didn't like which they should do better?
#  Nothing at all! We're worked with smaller companies where everything rotates around 1-2 people.
#
#
#  Show full review
#  Hide full review
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  1
#
#
#  2
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 205 E Harmon Ave, apt 904, Las Vegas, NV - 89169 United States
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  Privacy       Terms of use
#
#
#
#
#  About
#
#  Why GoodFirms
#  Contact Us
#  Glossary
#  Blogs
#  Help Center
#
#
#
#
#
#  For User
#
#  Research Methodology
#  Find Services
#  Find Software
#  Insights
#  Write a Review
#
#
#
#  For Business
#
#  Get Listed
#  Why Get Listed?
#  Build Your Profile
#  Boost Your Profile
#  Vendor Login
#
#
#
#
#
#
#  Copyright © GoodFirms 2023 | All rights reserved

# %%
def get_and_parse(url):
  response = requests.get(url)

# Parse the HTML content with Beautiful Soup
  soup = BeautifulSoup(response.content, 'html.parser')

# Remove unwanted elements (script, style, comments, etc.)
  for element in soup(['script', 'style', 'comment']):
      element.extract()

# Extract the visible text
  text = soup.get_text(separator=' ')
  return text

print(get_and_parse('https://www.goodfirms.co/company/webfx/reviews'))
# Out:
#
#
#
#
#
#
#
#
#
#
#
#  WebFX Reviews & Company Profile | GoodFirms
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  Sign In
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  Find Services
#
#
#
#  Software Development
#
#
#  Custom Software Developers
#  Blockchain Development
#  Java Development
#  PHP Development
#  Python Development
#  React Development
#  AngularJS Development
#  NodeJS Development
#  .Net Development
#  Software Testing
#
#
#
#
#  Web & App Development
#
#
#  Mobile App Development
#  Web Development
#  E-Commerce Development
#  Android App Development
#  iPhone App Development
#  Flutter App Development
#  WordPress Development
#  Magento Development
#  Shopify Development
#  WooCommerce Development
#
#
#
#
#  Design
#
#
#  Web Design
#  Graphic Design
#  UX Design
#  Product Design
#  Logo Design
#  Digital Design
#  Illustrators
#  Packaging Design
#  Print Design
#  Animation & Multimedia
#
#
#
#
#  Marketing & Advertising
#
#
#  Digital Marketing
#  SEO Agencies
#  Advertising
#  Social Media Marketing
#  Content Marketing
#  PPC Agencies
#  Branding
#  Email Marketing
#  Market Research
#  Influencer Marketing
#
#
#
#
#  Latest Tech
#
#
#  Artificial Intelligence
#  AR & VR Development
#  IoT Development
#  Bot Development
#  DevOps
#  Progressive Web App
#  Robotic Process Automation
#  ChatGPT Development
#  Metaverse Development
#
#
#
#
#  Business & IT Services
#
#
#  IT Services
#  Big Data Companies
#  Implementation Services
#  Cloud Computing Services
#  Business Services
#  IT Consulting
#  BPO Services
#  Admin Services
#  Translation Services
#  Supply Chain & Logistics
#
#
#
#
#  Browse all categories
#
#
#
#
#
#  Find Software
#
#
#
#
#
#  Write a Review
#  Insights
#  Blogs
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  WebFX
#  The Digital Marketing Agency That Drives Results
#
#
#
#
#  4.8
#
#
#  24  Reviews
#
#
#  Visit website
#
#
#
#  Write a Review
#
#
#
#
#  Verified Profile
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  Overview
#
#
#  Focus
#
#
#  Portfolio
#
#
#  Reviews
#
#
#  Visit website
#
#
#
#
#
#
#
#
#
#  WebFX is a tech-enabled digital marketing solutions provider, and we create custom strategies for each of our clients based on their needs and goals. Our team is made up of award-winning marketers, designers, and developers, and we know what it takes to get real results online. We also keep the focus on the metrics that mean the most, like leads and revenue generated. We know that hitting these goals is what moves businesses forward, and we believe that our client’s success is the best measure of our own performance.
#
#
#  Read more
#
#
#
#
#
#
#
#
#  $100 - $149/hr
#
#
#
#
#
#
#
#  250 - 999
#
#
#
#
#
#
#
#  1996
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Locations
#
#  Show All
#  Show Less
#
#
#
#
# United States
#
#
#  1705 North Front Street ,
#  Harrisburg ,
#  Pennsylvania
#  17102
#
#  8448562428
#
#
#
# United States
#
#
#  600 Third Avenue, 2nd Floor ,
#  NYC ,
#  New York
#  10016
#
#  8448562428
#
#
#
# United States
#
#
#  1000 Parkwood Circle SE #900 ,
#  Atlanta ,
#  Georgia
#  30339
#
#  8448562428
#
#
#
# United States
#
#
#  325 Chestnut Street Suite 800 ,
#  Philadelphia ,
#  Pennsylvania
#  19106
#
#  8448562428
#
#
#
#
#
#
#
#
#  Focus Areas
#
#  Service Focus
#
#
# 70%
#
#
# 10%
#
#
# 10%
#
#
# 10%
#
#
#
#  Digital Marketing
#  Web Development
#  Web Designing (UI/UX)
#  E-commerce Development
#
#
#
#
#
#
# Digital Marketing
#
#
# 70%
#
#
#
#
# Web Development
#
#
# 10%
#
#
#
#
# Web Designing (UI/UX)
#
#
# 10%
#
#
#
#
# E-commerce Development
#
#
# 10%
#
#
#
#
#
#
#
#
#
#
#  Client Focus
#
#
# 55%
#
#
# 5%
#
#
# 40%
#
#
#
#  Medium Business
#  Large Business
#  Small Business
#
#
#
#
#
#  Medium Business($10M - $1B)
#  55%
#
#
#  Large Business(> $1B)
#  5%
#
#
#  Small Business(< $10M)
#  40%
#
#
#
#
#
#
#
#
#
#
#
#
#  WebFX Clients & Portfolios
#
#
#
#
#
#
#
#
#
#
#
#
#  View Portfolio
#
#
#  Energex
#
#
#
#
#
#
#
#
#
#
#
#  $10001 to $50000
#
#
#
#  12 weeks
#
#
#
#  Consumer Products
#
#
#  Website redesign for a leading manufacturer of premium wood pellets. The site features unique icons and imagery with a responsive design and strong calls to action.
#
#
#  Web App
#
#
#
#
#
#
#
#  View Portfolio
#
#
#  NeoSystems
#
#
#
#
#
#
#
#
#
#
#
#  $10001 to $50000
#
#
#
#  20 weeks
#
#
#
#  Information Technology
#
#
#  Website redesign for a software company. We launched a complete redesign of their website to better showcase the amazing products and software that they offer.
#
#
#  Web App
#
#
#
#
#
#
#
#
#
#  WebFX Reviews
#
#
#
#
#
#  4.8
#  24 Reviews
#
#
#
#  Services:
#
#
#
#
#
#
#
#  All
# Services
#
#  Digital Marketing
#  Web Development
#  Web Designing (UI/UX)
#
#
#
#
#  Sort By:
#
#
#
#
#
#
#
#
# Relevance
#
#
# Most Recent
#
#
# Rating: high to low
#
#
# Rating: low to high
#
#
#
#
#  Write a Review
#
#
#
#
#
#
#
#
#
#  Lakshmi Nedungadi , Business Strategist at Self Employed
#  Posted 11 months ago
#
#
#
#  They helped us increase the organic traffic.
#
#
#
#  Rating Breakdown
#
#
#  Quality
#
#
#
#
#
#  Schedule & Timing
#
#
#
#
#
#  Communication
#
#
#
#
#
#  Overall Rating
#
#
#
#
#
#
#
#  Project Detail
#
#
#
#  $50001 to $200000
#
#
#
#
#
#  Completed
#
#
#
#
#  Share it on
#
#
#
#
#
#
#
#
#
#  Review Summary
#
# WebFX is outstanding at what they do and is one of the best SEO and digital marketing companies in the country. I've worked with WebFX for many years and they always bring new ideas to our campaigns which deliver strong results. In addition to strong performance, everyone that I've ever spoken with is extremely friendly and WebFX provides excellent customer service.
#
#
#
#
#  What was the project name that you have worked with WebFX?
#  Blockchain development and and crypto exchange
#
#
#  Describe your project in brief
#  I am thrilled to share my experience working with Cryptosoftwares. Their high quality service has amazed me to the core. I have worked with them for multiple projects like blockchain development and crypto exchange
#
#
#  What is it about the company that you appreciate the most?
#  The people and the results that WebFX was able to achieve on our digital campaigns.
#
#
#  What was it about the company that you didn't like which they should do better?
#  The people and the results that WebFX was able to achieve on our digital campaigns.
#
#
#  Show full review
#  Hide full review
#
#
#
#
#
#
#
#
#
#   Chester Peters  at WebFX
#  Posted on Jun 20, 2022
#
#
#
#  They've been nothing but helpful, responsive, and considerate of feedback
#
#
#
#  Rating Breakdown
#
#
#  Quality
#
#
#
#
#
#  Schedule & Timing
#
#
#
#
#
#  Communication
#
#
#
#
#
#  Overall Rating
#
#
#
#
#
#
#
#  Project Detail
#
#
#
#  $0 to $10000
#
#
#
#
#  Share it on
#
#
#
#
#
#
#
#
#
#  Review Summary
#
# The best web designers in the town and they are best in whole town as my website was beautifully designed and it was ranked too in the best websites.
#
#
#
#
#  What is it about the company that you appreciate the most?
#  {"1":"Help was quick and helpful throughout the website building process, and the after-sales support was exceptional as well"}
#
#
#  What was it about the company that you didn't like which they should do better?
#  {"1":"Your requests will be met with prompt honesty and straightforwardness. but sometime no time work not provied"}
#
#
#  Show full review
#  Hide full review
#
#
#
#
#
#
#
#
#
#  P S Kumar
#  Posted on Aug 06, 2021
#
#
#
#  Good Services
#
#
#
#  Rating Breakdown
#
#
#  Quality
#
#
#
#
#
#  Schedule & Timing
#
#
#
#
#
#  Communication
#
#
#
#
#
#  Overall Rating
#
#
#
#
#
#
#
#  Share it on
#
#
#
#
#
#
#
#
#
#  Review Summary
#
# The guys are very professional that deliver best in this industries.
#
#
#
#
#  Show full review
#  Hide full review
#
#
#
#
#
#
#
#
#
#  Emma Gomez
#  Posted on Apr 08, 2021
#
#
#
#  Great Exper
#
#
#
#  Rating Breakdown
#
#
#  Quality
#
#
#
#
#
#  Schedule & Timing
#
#
#
#
#
#  Communication
#
#
#
#
#
#  Overall Rating
#
#
#
#
#
#
#
#  Share it on
#
#
#
#
#
#
#
#
#
#  Review Summary
#
# Experience with RankSnack was Great I like there working approach and overall client handling skills, They ranked my website in Google for the selected Keywords.
#
#
#
#
#  Show full review
#  Hide full review
#
#
#
#
#
#
#
#
#
#  Noah John
#  Posted on Dec 25, 2020
#
#
#
#  Wonderful!
#
#
#
#  Rating Breakdown
#
#
#  Quality
#
#
#
#
#
#  Schedule & Timing
#
#
#
#
#
#  Communication
#
#
#
#
#
#  Overall Rating
#
#
#
#
#
#
#
#  Share it on
#
#
#
#
#
#
#
#
#
#  Review Summary
#
# The team at WebFX makes my life so much easier! Seamless planning of events and support during. The team is very responsive and fun to work with! I can't say enough about them! Wonderful!
#
#
#
#
#  Show full review
#  Hide full review
#
#
#
#
#
#
#
#
#
#  Dai Software
#  Posted on Dec 01, 2020
#
#
#
#  multi vendor ecommerce website price
#
#
#
#  Rating Breakdown
#
#
#  Quality
#
#
#
#
#
#  Schedule & Timing
#
#
#
#
#
#  Communication
#
#
#
#
#
#  Overall Rating
#
#
#
#
#
#
#
#  Share it on
#
#
#
#
#
#
#
#
#
#  Review Summary
#
# I completely agree, It is great. And I am always surprised when I read posts about the food. This great content. I have learned something powerful today. multi vendor ecommerce website price
#
#
#
#
#  Show full review
#  Hide full review
#
#
#
#
#
#
#
#
#
#  GVI TECH
#  Posted on Aug 20, 2020
#
#
#
#  Seo service provider
#
#
#
#  Rating Breakdown
#
#
#  Quality
#
#
#
#
#
#  Schedule & Timing
#
#
#
#
#
#  Communication
#
#
#
#
#
#  Overall Rating
#
#
#
#
#
#
#
#  Share it on
#
#
#
#
#
#
#
#
#
#  Review Summary
#
# GVI Technology provides the best SEO service.In SEO service these works include like more brand awareness, more business growth, and more leads, more traffic etc.when you gain more visibility you will find the more no of visitors to your website, that's why the traffic also increases. Lastly, you will find your development in your business.
#
#
#
#
#  Show full review
#  Hide full review
#
#
#
#
#
#
#
#
#
#  Anil Sharma  at Dr. Anil sharma laparoscopy
#  Posted on Jul 10, 2020
#
#
#
#  Digital marketing
#
#
#
#  Rating Breakdown
#
#
#  Quality
#
#
#
#
#
#  Schedule & Timing
#
#
#
#
#
#  Communication
#
#
#
#
#
#  Overall Rating
#
#
#
#
#
#
#
#  Share it on
#
#
#
#
#
#
#
#
#
#  Review Summary
#
# Great relationship building and communication throughout the company. Very impressive work.
# http://www.anilsharmalaparoscopy.com/hernia.php
#
#
#
#
#  Show full review
#  Hide full review
#
#
#
#
#
#
#
#
#
#  Jack Houston
#  Posted on Apr 21, 2020
#
#
#
#  A top tier experience
#
#
#
#  Rating Breakdown
#
#
#  Quality
#
#
#
#
#
#  Schedule & Timing
#
#
#
#
#
#  Communication
#
#
#
#
#
#  Overall Rating
#
#
#
#
#
#
#
#  Project Detail
#
#
#
#  $0 to $10000
#
#
#
#
#  Share it on
#
#
#
#
#
#
#
#
#
#  Review Summary
#
# Great relationship building and communication throughout the company. Very impressive work.
#
#
#
#
#  What is it about the company that you appreciate the most?
#  Great people and quick turnaround
#
#
#  What was it about the company that you didn't like which they should do better?
#  No negatives at all
#
#
#  Show full review
#  Hide full review
#
#
#
#
#
#
#
#
#
#  Raymond McClure
#  Posted on Feb 14, 2020
#
#
#
#  Great experience!
#
#
#
#  Rating Breakdown
#
#
#  Quality
#
#
#
#
#
#  Schedule & Timing
#
#
#
#
#
#  Communication
#
#
#
#
#
#  Overall Rating
#
#
#
#
#
#
#
#  Project Detail
#
#
#
#  $10001 to $50000
#
#
#
#
#  Share it on
#
#
#
#
#
#
#
#
#
#  Review Summary
#
# Overall very happy with WebFX - always there when I need them. Amanda has been a huge help and she's got a great team backing her up day in and day out.
#
#
#
#
#  What is it about the company that you appreciate the most?
#  Always there when I need them for random questions
#
#
#  What was it about the company that you didn't like which they should do better?
#  I don't always understand the acronyms in the digital marketing world.
#
#
#  Show full review
#  Hide full review
#
#
#
#
#
#
#
#
#
#  Vaibhav Kandpal , Digital Strategy Consultant at TIS
#  Posted on May 17, 2019
#
#
#
#  Great Company
#
#
#
#  Rating Breakdown
#
#
#  Quality
#
#
#
#
#
#  Schedule & Timing
#
#
#
#
#
#  Communication
#
#
#
#
#
#  Overall Rating
#
#
#
#
#
#
#
#  Share it on
#
#
#
#
#
#
#
#
#
#  Review Summary
#
# Great compapny to avail services of. Will be returning to them again.
#
#
#
#
#  Show full review
#  Hide full review
#
#
#
#
#
#
#
#
#
#  James Ritchie Espino Ostman , Co Op / Validation Specialist at Barry-Wehmiller Design Group
#  Posted on Mar 13, 2019
#
#
#
#  Highly recommend this company!
#
#
#
#  Rating Breakdown
#
#
#  Quality
#
#
#
#
#
#  Schedule & Timing
#
#
#
#
#
#  Communication
#
#
#
#
#
#  Overall Rating
#
#
#
#
#
#
#
#  Project Detail
#
#
#
#  $10001 to $50000
#
#
#
#
#  Share it on
#
#
#
#
#
#
#
#
#
#  Review Summary
#
# Will and the rest of the WebFX team knows PPC really well. I think they have 6-7 people working on our account at any given time. Strongly suggest!
#
#
#
#
#  What is it about the company that you appreciate the most?
#  Our cost per lead has decreased by 25% over the past 6 months!
#
#
#  What was it about the company that you didn't like which they should do better?
#  Not sure, the setup took a few weeks with all the research and strategy planning, however now our CPL has decreased a lot worth the extra setup time.
#
#
#
#  Show full review
#  Hide full review
#
#
#
#
#
#
#
#
#
#  Jenny Blevins , Business Analyst at Dell
#  Posted on Feb 19, 2019
#
#
#
#  Trustworthy company
#
#
#
#  Rating Breakdown
#
#
#  Quality
#
#
#
#
#
#  Schedule & Timing
#
#
#
#
#
#  Communication
#
#
#
#
#
#  Overall Rating
#
#
#
#
#
#
#
#  Share it on
#
#
#
#
#
#
#
#
#
#  Review Summary
#
# I have worked with them for 2 projects now, including one at my old position. They approach all projects big or small the same way. I reccomended a family friend use them for their landscaping business and they didn't have a huge budget but WebFX was so very helpful to them and helped educate them.
#
#
#
#
#  Show full review
#  Hide full review
#
#
#
#
#
#
#
#
#
#  Robert Lee Barner , Senior Manager Quality Engineering at Amicus Therapeutics
#  Posted on Feb 18, 2019
#
#
#
#  This was the best website/marketing company we have ever worked with!
#
#
#
#  Rating Breakdown
#
#
#  Quality
#
#
#
#
#
#  Schedule & Timing
#
#
#
#
#
#  Communication
#
#
#
#
#
#  Overall Rating
#
#
#
#
#
#
#
#  Project Detail
#
#
#
#  $10001 to $50000
#
#
#
#
#  Share it on
#
#
#
#
#
#
#
#
#
#  Review Summary
#
# The overall experience was great! Our website looks amazing, and we are generating solid leads from our PPC campaign. WebFX is a very professional company, and our project manager (Kristina) was a rock star!
#
#
#
#
#  What is it about the company that you appreciate the most?
#  The website looks amazing!
#
#
#  What was it about the company that you didn't like which they should do better?
#  Not really an improvement but we learned how hard good web design is to do! The website redesign was a ton of work, and took 2 weeks longer then we wanted it to. I didn't realize building a website would be so much work.
#
#
#  Show full review
#  Hide full review
#
#
#
#
#
#
#
#
#
#  Greg Shambaugh , Teacher at West Shore School District
#  Posted on Feb 15, 2019
#
#
#
#  The communication is unparalelled!
#
#
#
#  Rating Breakdown
#
#
#  Quality
#
#
#
#
#
#  Schedule & Timing
#
#
#
#
#
#  Communication
#
#
#
#
#
#  Overall Rating
#
#
#
#
#
#
#
#  Project Detail
#
#
#
#  $50001 to $200000
#
#
#
#
#  Share it on
#
#
#
#
#
#
#
#
#
#  Review Summary
#
# They are a real company! At first we weren't sure about going to a larger agency, so we opted to choose a smaller boutique company. That was a big mistake! Our main poc got married and was out for 3 weeks, well nothing got done for 3 weeks. We never have to worry about this with WebFX. Paul is our main marketer, however there is a small army behind him so we are always taken care of, and their project managment software ensure emails, communication and task are never missed! We love it!
#
#
#
#
#  What is it about the company that you appreciate the most?
#  They are a real company and have driven our company real leads!
#
#
#  What was it about the company that you didn't like which they should do better?
#  Nothing at all! We're worked with smaller companies where everything rotates around 1-2 people.
#
#
#  Show full review
#  Hide full review
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  1
#
#
#  2
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 205 E Harmon Ave, apt 904, Las Vegas, NV - 89169 United States
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  Privacy       Terms of use
#
#
#
#
#  About
#
#  Why GoodFirms
#  Contact Us
#  Glossary
#  Blogs
#  Help Center
#
#
#
#
#
#  For User
#
#  Research Methodology
#  Find Services
#  Find Software
#  Insights
#  Write a Review
#
#
#
#  For Business
#
#  Get Listed
#  Why Get Listed?
#  Build Your Profile
#  Boost Your Profile
#  Vendor Login
#
#
#
#
#
#
#  Copyright © GoodFirms 2023 | All rights reserved

# %%
pip install requests beautifulsoup4 requests-html
# Out:
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (2.31.0)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (4.11.2)
# Collecting requests-html
#   Downloading requests_html-0.10.0-py3-none-any.whl (13 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests) (3.3.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests) (2023.7.22)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4) (2.5)
# Collecting pyquery (from requests-html)
#   Downloading pyquery-2.0.0-py3-none-any.whl (22 kB)
# Collecting fake-useragent (from requests-html)
#   Downloading fake_useragent-1.3.0-py3-none-any.whl (15 kB)
# Collecting parse (from requests-html)
#   Downloading parse-1.19.1-py2.py3-none-any.whl (18 kB)
# Collecting bs4 (from requests-html)
#   Downloading bs4-0.0.1.tar.gz (1.1 kB)
#   Preparing metadata (setup.py) ... done
# Collecting w3lib (from requests-html)
#   Downloading w3lib-2.1.2-py3-none-any.whl (21 kB)
# Collecting pyppeteer>=0.0.14 (from requests-html)
#   Downloading pyppeteer-1.0.2-py3-none-any.whl (83 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 83.4/83.4 kB 5.5 MB/s eta 0:00:00
# Requirement already satisfied: appdirs<2.0.0,>=1.4.3 in /usr/local/lib/python3.10/dist-packages (from pyppeteer>=0.0.14->requests-html) (1.4.4)
# Requirement already satisfied: importlib-metadata>=1.4 in /usr/local/lib/python3.10/dist-packages (from pyppeteer>=0.0.14->requests-html) (6.8.0)
# Collecting pyee<9.0.0,>=8.1.0 (from pyppeteer>=0.0.14->requests-html)
#   Downloading pyee-8.2.2-py2.py3-none-any.whl (12 kB)
# Requirement already satisfied: tqdm<5.0.0,>=4.42.1 in /usr/local/lib/python3.10/dist-packages (from pyppeteer>=0.0.14->requests-html) (4.66.1)
# Collecting urllib3<3,>=1.21.1 (from requests)
#   Downloading urllib3-1.26.18-py2.py3-none-any.whl (143 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 143.8/143.8 kB 6.3 MB/s eta 0:00:00
# Collecting websockets<11.0,>=10.0 (from pyppeteer>=0.0.14->requests-html)
#   Downloading websockets-10.4-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (106 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 106.8/106.8 kB 8.0 MB/s eta 0:00:00
# Requirement already satisfied: lxml>=2.1 in /usr/local/lib/python3.10/dist-packages (from pyquery->requests-html) (4.9.3)
# Collecting cssselect>=1.2.0 (from pyquery->requests-html)
#   Downloading cssselect-1.2.0-py2.py3-none-any.whl (18 kB)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.10/dist-packages (from importlib-metadata>=1.4->pyppeteer>=0.0.14->requests-html) (3.17.0)
# Building wheels for collected packages: bs4
#   Building wheel for bs4 (setup.py) ... done
#   Created wheel for bs4: filename=bs4-0.0.1-py3-none-any.whl size=1256 sha256=a9e1a2b680671b44b96bd3977f996aa17470ec41ab6ebe9aa54b9e77273e0f04
#   Stored in directory: /root/.cache/pip/wheels/25/42/45/b773edc52acb16cd2db4cf1a0b47117e2f69bb4eb300ed0e70
# Successfully built bs4
# Installing collected packages: pyee, parse, fake-useragent, websockets, w3lib, urllib3, cssselect, pyquery, pyppeteer, bs4, requests-html
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 2.0.7
#     Uninstalling urllib3-2.0.7:
#       Successfully uninstalled urllib3-2.0.7
# Successfully installed bs4-0.0.1 cssselect-1.2.0 fake-useragent-1.3.0 parse-1.19.1 pyee-8.2.2 pyppeteer-1.0.2 pyquery-2.0.0 requests-html-0.10.0 urllib3-1.26.18 w3lib-2.1.2 websockets-10.4

# %%
import pandas as pd
from urllib.parse import urlparse
import numpy as np
import nltk.data
from requests_html import HTMLSession

# %%
def parse_elements(url,element):
    session = HTMLSession()
    r = session.get(url)
    elements = r.html.find(element)
    return elements

# %%
url = 'https://www.goodfirms.co/company/webfx/reviews'

# %%
paragraphs = parse_elements(url, 'p')
links = parse_elements(url, 'a')

# %%
(paragraphs[0]).html
# Out:
# '<p class="profile-tagline">The Digital Marketing Agency That Drives Results</p>'

# %%
set1 = {'a','a','b',3,7}

# %%
links_set = set()
for link in links:
  links_set.add(link.attrs['href'])
len(links_set)
# Out:
# 112

# %%
(paragraphs[0]).text
# Out:
# 'The Digital Marketing Agency That Drives Results'

# %%
for p in paragraphs:
  print(p.text)
# Out:
# The Digital Marketing Agency That Drives Results
# WebFX is a tech-enabled digital marketing solutions provider, and we create custom strategies for each of our clients based on their needs and goals. Our team is made up of award-winning marketers, designers, and developers, and we know what it takes to get real results online. We also keep the focus on the metrics that mean the most, like leads and revenue generated. We know that hitting these goals is what moves businesses forward, and we believe that our client’s success is the best measure of our own performance.
# Website redesign for a leading manufacturer of premium wood pellets. The site features unique icons and imagery with a responsive design and strong calls to action.
# Website redesign for a software company. We launched a complete redesign of their website to better showcase the amazing products and software that they offer.
# Blockchain development and and crypto exchange
# I am thrilled to share my experience working with Cryptosoftwares. Their high quality service has amazed me to the core. I have worked with them for multiple projects like blockchain development and crypto exchange
# The people and the results that WebFX was able to achieve on our digital campaigns.
# The people and the results that WebFX was able to achieve on our digital campaigns.
# {"1":"Help was quick and helpful throughout the website building process, and the after-sales support was exceptional as well"}
# {"1":"Your requests will be met with prompt honesty and straightforwardness. but sometime no time work not provied"}
# Great people and quick turnaround
# No negatives at all
# Always there when I need them for random questions
# I don't always understand the acronyms in the digital marketing world.
# Our cost per lead has decreased by 25% over the past 6 months!
# Not sure, the setup took a few weeks with all the research and strategy planning, however now our CPL has decreased a lot worth the extra setup time.
# The website looks amazing!
# Not really an improvement but we learned how hard good web design is to do! The website redesign was a ton of work, and took 2 weeks longer then we wanted it to. I didn't realize building a website would be so much work.
# They are a real company and have driven our company real leads!
# Nothing at all! We're worked with smaller companies where everything rotates around 1-2 people.

# %%
def sentiment_detection(sentence):
    positive_words = ('great', 'good', 'benefits', 'great team', 'great', 'amazing')
    negative_words = ('No work-life balance', 'long', 'low', 'demaning', 'toxic')

    positive = any(sentence.count(i) > 0 for i in positive_words)
    negative = any(sentence.count(i) > 0 for i in negative_words)

    if positive == negative == False:
        return "neutral"
    elif positive != negative:
        return "positive" if positive else "negative"
    else:
        return "mixed"

# %%
#repurpose our sentiment analysis as topic detection
#detect if EY has a positive review from employees?
def topic_detection(sentence):
    Positive_words = ('best', 'new ideas', 'excellent', 'easy', 'great', 'achieve', 'high')
    negative_words = ('worst', 'no work-life balance', 'long hours', 'bad')
    Positive = any(sentence.count(i) > 0 for i in Positive_words)
    Negative = any(sentence.count(i)>0 for i in negative_words )
    topics = []
    if Positive == True:
        topics.append("Positive")
    if Negative == True:
      topics.apend("Negative")
    return topics

# %%
#requirements: print out a sentiment analysis after every paragraph prints out
#print(paragraphs)
for p in range(0, len(paragraphs)):
    if len(paragraphs[p].text) > 50:
      print((paragraphs[p].text))
      print(f"TALKS ABOUT: {topic_detection(paragraphs[p].text)}")
# Out:
# WebFX is a tech-enabled digital marketing solutions provider, and we create custom strategies for each of our clients based on their needs and goals. Our team is made up of award-winning marketers, designers, and developers, and we know what it takes to get real results online. We also keep the focus on the metrics that mean the most, like leads and revenue generated. We know that hitting these goals is what moves businesses forward, and we believe that our client’s success is the best measure of our own performance.
# TALKS ABOUT: ['Positive']
# Website redesign for a leading manufacturer of premium wood pellets. The site features unique icons and imagery with a responsive design and strong calls to action.
# TALKS ABOUT: []
# Website redesign for a software company. We launched a complete redesign of their website to better showcase the amazing products and software that they offer.
# TALKS ABOUT: []
# I am thrilled to share my experience working with Cryptosoftwares. Their high quality service has amazed me to the core. I have worked with them for multiple projects like blockchain development and crypto exchange
# TALKS ABOUT: ['Positive']
# The people and the results that WebFX was able to achieve on our digital campaigns.
# TALKS ABOUT: ['Positive']
# The people and the results that WebFX was able to achieve on our digital campaigns.
# TALKS ABOUT: ['Positive']
# {"1":"Help was quick and helpful throughout the website building process, and the after-sales support was exceptional as well"}
# TALKS ABOUT: []
# {"1":"Your requests will be met with prompt honesty and straightforwardness. but sometime no time work not provied"}
# TALKS ABOUT: []
# I don't always understand the acronyms in the digital marketing world.
# TALKS ABOUT: []
# Our cost per lead has decreased by 25% over the past 6 months!
# TALKS ABOUT: []
# Not sure, the setup took a few weeks with all the research and strategy planning, however now our CPL has decreased a lot worth the extra setup time.
# TALKS ABOUT: []
# Not really an improvement but we learned how hard good web design is to do! The website redesign was a ton of work, and took 2 weeks longer then we wanted it to. I didn't realize building a website would be so much work.
# TALKS ABOUT: []
# They are a real company and have driven our company real leads!
# TALKS ABOUT: []
# Nothing at all! We're worked with smaller companies where everything rotates around 1-2 people.
# TALKS ABOUT: []

# %%
def sentiment_detection(sentence):
    positive_words = ('best', 'new ideas', 'excellent', 'easy', 'great', 'achieve', 'high')
    negative_words = ('worst', 'no work-life balance', 'long hours', 'bad')

    positive = any(sentence.count(i) > 0 for i in positive_words)
    negative = any(sentence.count(i) > 0 for i in negative_words)

    if positive == negative == False:
        return "neutral"
    elif positive != negative:
        return "positive" if positive else "negative"
    else:
        return "mixed"

# %%
#requirements: print out a topic analysis after every paragraph prints out
#dictionary that has two lists, one for the paragraphs, and one for topics covered by those paragraphs
#print(paragraphs)
p_dictionary = {}
p_list = []
topic_list = []
for p in range(0, len(paragraphs)):
    if len(paragraphs[p].text) > 50:
      #print((paragraphs[p].text))
      #print(f"TALKS ABOUT: {topic_detection(paragraphs[p].text)}")
      p_list.append(paragraphs[p].text)
      topic_list.append(topic_detection(paragraphs[p].text))
p_dictionary['Paragraphs'] = p_list
p_dictionary['Topics'] = topic_list

# %%
p_dictionary['Topics']
# Out:
# [['Positive'],
#  [],
#  [],
#  ['Positive'],
#  ['Positive'],
#  ['Positive'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  []]

# %%
medium_df = pd.DataFrame(p_dictionary)

# %%
medium_df.head(9)
# Out:
#                                           Paragraphs      Topics
# 0  WebFX is a tech-enabled digital marketing solu...  [Positive]
# 1  Website redesign for a leading manufacturer of...          []
# 2  Website redesign for a software company. We la...          []
# 3  I am thrilled to share my experience working w...  [Positive]
# 4  The people and the results that WebFX was able...  [Positive]
# 5  The people and the results that WebFX was able...  [Positive]
# 6  {"1":"Help was quick and helpful throughout th...          []
# 7  {"1":"Your requests will be met with prompt ho...          []
# 8  I don't always understand the acronyms in the ...          []

# %%
medium_df['Character Count'] = medium_df['Paragraphs'].apply(lambda x: len(x))

# %%
medium_df.head(10)
# Out:
#                                           Paragraphs      Topics  \
# 0  WebFX is a tech-enabled digital marketing solu...  [Positive]
# 1  Website redesign for a leading manufacturer of...          []
# 2  Website redesign for a software company. We la...          []
# 3  I am thrilled to share my experience working w...  [Positive]
# 4  The people and the results that WebFX was able...  [Positive]
# 5  The people and the results that WebFX was able...  [Positive]
# 6  {"1":"Help was quick and helpful throughout th...          []
# 7  {"1":"Your requests will be met with prompt ho...          []
# 8  I don't always understand the acronyms in the ...          []
# 9  Our cost per lead has decreased by 25% over th...          []
#
#    Character Count
# 0              522
# 1              164
# 2              159
# 3              214
# 4               83
# 5               83
# 6              127
# 7              116
# 8               70
# 9               62

# %%
medium_df2 = pd.DataFrame({'Paragraph_Elements':paragraphs})

# %%
medium_df2.head()
# Out:
#                          Paragraph_Elements
# 0  <Element 'p' class=('profile-tagline',)>
# 1                            <Element 'p' >
# 2                            <Element 'p' >
# 3                            <Element 'p' >
# 4                            <Element 'p' >

# %%
medium_df2['Paragraph_Text'] = medium_df2['Paragraph_Elements'].apply(lambda x:x.text)

# %%
medium_df2.head()
# Out:
#                          Paragraph_Elements  \
# 0  <Element 'p' class=('profile-tagline',)>
# 1                            <Element 'p' >
# 2                            <Element 'p' >
# 3                            <Element 'p' >
# 4                            <Element 'p' >
#
#                                       Paragraph_Text
# 0   The Digital Marketing Agency That Drives Results
# 1  WebFX is a tech-enabled digital marketing solu...
# 2  Website redesign for a leading manufacturer of...
# 3  Website redesign for a software company. We la...
# 4     Blockchain development and and crypto exchange

# %%
medium_df2['Topics'] = medium_df2['Paragraph_Text'].apply(topic_detection)

# %%
medium_df2.head()
# Out:
#                          Paragraph_Elements  \
# 0  <Element 'p' class=('profile-tagline',)>
# 1                            <Element 'p' >
# 2                            <Element 'p' >
# 3                            <Element 'p' >
# 4                            <Element 'p' >
#
#                                       Paragraph_Text      Topics
# 0   The Digital Marketing Agency That Drives Results          []
# 1  WebFX is a tech-enabled digital marketing solu...  [Positive]
# 2  Website redesign for a leading manufacturer of...          []
# 3  Website redesign for a software company. We la...          []
# 4     Blockchain development and and crypto exchange          []

# %%
medium_df2['Character Count'] = medium_df2['Paragraph_Text'].apply(lambda x: len(x))

# %%
medium_df2.head()
# Out:
#                          Paragraph_Elements  \
# 0  <Element 'p' class=('profile-tagline',)>
# 1                            <Element 'p' >
# 2                            <Element 'p' >
# 3                            <Element 'p' >
# 4                            <Element 'p' >
#
#                                       Paragraph_Text      Topics  \
# 0   The Digital Marketing Agency That Drives Results          []
# 1  WebFX is a tech-enabled digital marketing solu...  [Positive]
# 2  Website redesign for a leading manufacturer of...          []
# 3  Website redesign for a software company. We la...          []
# 4     Blockchain development and and crypto exchange          []
#
#    Character Count
# 0               48
# 1              522
# 2              164
# 3              159
# 4               46

# %%
medium_df2 = medium_df2[medium_df2['Character Count'] >= 50]

# %%
medium_df2
# Out:
#    Paragraph_Elements                                     Paragraph_Text  \
# 1      <Element 'p' >  WebFX is a tech-enabled digital marketing solu...
# 2      <Element 'p' >  Website redesign for a leading manufacturer of...
# 3      <Element 'p' >  Website redesign for a software company. We la...
# 5      <Element 'p' >  I am thrilled to share my experience working w...
# 6      <Element 'p' >  The people and the results that WebFX was able...
# 7      <Element 'p' >  The people and the results that WebFX was able...
# 8      <Element 'p' >  {"1":"Help was quick and helpful throughout th...
# 9      <Element 'p' >  {"1":"Your requests will be met with prompt ho...
# 12     <Element 'p' >  Always there when I need them for random quest...
# 13     <Element 'p' >  I don't always understand the acronyms in the ...
# 14     <Element 'p' >  Our cost per lead has decreased by 25% over th...
# 15     <Element 'p' >  Not sure, the setup took a few weeks with all ...
# 17     <Element 'p' >  Not really an improvement but we learned how h...
# 18     <Element 'p' >  They are a real company and have driven our co...
# 19     <Element 'p' >  Nothing at all! We're worked with smaller comp...
#
#         Topics  Character Count
# 1   [Positive]              522
# 2           []              164
# 3           []              159
# 5   [Positive]              214
# 6   [Positive]               83
# 7   [Positive]               83
# 8           []              127
# 9           []              116
# 12          []               50
# 13          []               70
# 14          []               62
# 15          []              149
# 17          []              220
# 18          []               63
# 19          []               95

# %%
medium_df['Character Count'] = medium_df['Paragraphs'].apply(lambda x: len(x))

# %%
medium_df['Topic Count'] = medium_df['Topics'].apply(len)
medium_df.head()
# Out:
#                                           Paragraphs      Topics  \
# 0  WebFX is a tech-enabled digital marketing solu...  [Positive]
# 1  Website redesign for a leading manufacturer of...          []
# 2  Website redesign for a software company. We la...          []
# 3  I am thrilled to share my experience working w...  [Positive]
# 4  The people and the results that WebFX was able...  [Positive]
#
#    Character Count  Topic Count
# 0              522            1
# 1              164            0
# 2              159            0
# 3              214            1
# 4               83            1

# %%
medium_df['Sentiment'] = medium_df['Paragraphs'].apply(sentiment_detection)

# %%
medium_df.head(10)
# Out:
#                                           Paragraphs      Topics  \
# 0  WebFX is a tech-enabled digital marketing solu...  [Positive]
# 1  Website redesign for a leading manufacturer of...          []
# 2  Website redesign for a software company. We la...          []
# 3  I am thrilled to share my experience working w...  [Positive]
# 4  The people and the results that WebFX was able...  [Positive]
# 5  The people and the results that WebFX was able...  [Positive]
# 6  {"1":"Help was quick and helpful throughout th...          []
# 7  {"1":"Your requests will be met with prompt ho...          []
# 8  I don't always understand the acronyms in the ...          []
# 9  Our cost per lead has decreased by 25% over th...          []
#
#    Character Count  Topic Count Sentiment
# 0              522            1  positive
# 1              164            0   neutral
# 2              159            0   neutral
# 3              214            1  positive
# 4               83            1  positive
# 5               83            1  positive
# 6              127            0   neutral
# 7              116            0   neutral
# 8               70            0   neutral
# 9               62            0   neutral

# %%
category_amount = medium_df['Sentiment'].value_counts()
print(category_amount)
print(list(category_amount))
print(list(category_amount.keys()))
# Out:
# neutral     10
# positive     4
# Name: Sentiment, dtype: int64
# [10, 4]
# ['neutral', 'positive']

# %%
medium_df['Webfx'] = np.where('Webfx' in medium_df['Topics'][0], 1, 0)

# %%
medium_df.head(9)
# Out:
#                                           Paragraphs      Topics  \
# 0  WebFX is a tech-enabled digital marketing solu...  [Positive]
# 1  Website redesign for a leading manufacturer of...          []
# 2  Website redesign for a software company. We la...          []
# 3  I am thrilled to share my experience working w...  [Positive]
# 4  The people and the results that WebFX was able...  [Positive]
# 5  The people and the results that WebFX was able...  [Positive]
# 6  {"1":"Help was quick and helpful throughout th...          []
# 7  {"1":"Your requests will be met with prompt ho...          []
# 8  I don't always understand the acronyms in the ...          []
#
#    Character Count  Topic Count Sentiment  Webfx
# 0              522            1  positive      0
# 1              164            0   neutral      0
# 2              159            0   neutral      0
# 3              214            1  positive      0
# 4               83            1  positive      0
# 5               83            1  positive      0
# 6              127            0   neutral      0
# 7              116            0   neutral      0
# 8               70            0   neutral      0

# %%
medium_df['Webfx'] = medium_df['Topics'].apply(lambda x:1 if 'webfx' in x else 0)

# %%
medium_df.head(9)
# Out:
#                                           Paragraphs      Topics  \
# 0  WebFX is a tech-enabled digital marketing solu...  [Positive]
# 1  Website redesign for a leading manufacturer of...          []
# 2  Website redesign for a software company. We la...          []
# 3  I am thrilled to share my experience working w...  [Positive]
# 4  The people and the results that WebFX was able...  [Positive]
# 5  The people and the results that WebFX was able...  [Positive]
# 6  {"1":"Help was quick and helpful throughout th...          []
# 7  {"1":"Your requests will be met with prompt ho...          []
# 8  I don't always understand the acronyms in the ...          []
#
#    Character Count  Topic Count Sentiment  Webfx  Data  AI
# 0              522            1  positive      0     0   0
# 1              164            0   neutral      0     0   0
# 2              159            0   neutral      0     0   0
# 3              214            1  positive      0     0   0
# 4               83            1  positive      0     0   0
# 5               83            1  positive      0     0   0
# 6              127            0   neutral      0     0   0
# 7              116            0   neutral      0     0   0
# 8               70            0   neutral      0     0   0

# %%
import matplotlib.pyplot as plt



# Extract category names and corresponding amounts
#categories = list(category_amount.keys())
#amounts = list(category_amount.values())

# Plotting the bar graph
plt.bar(list(category_amount.keys()), list(category_amount))

# Customize the plot
plt.xlabel('Sentiment')
plt.ylabel('Total Count')
plt.title('Total count of sentiment')
plt.xticks(rotation=45)

# Show the plot
plt.show()
